# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет !</b>
#
# Меня зовут Дмитрий Михаленко, я буду ревьюером второй части финального проекта. Если ты не против, то предлагаю построить наше общение на "ты" ;) Если удобнее на "вы", то нет проблем, только скажи об этом.
#
# Ниже в работе ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**.
#
# Для наглядности я буду использовать цветовую разметку:
# <font color='green'>зеленого</font>, <font color='gold'>желтого</font> и <font color='red'>красного</font> цветов. Сейчас объясню, что они значат:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Решение на этом шаге является полностью правильным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Решение на этом шаге может стать еще лучше, если внести небольшие коррективы.
# Но настаивать я не буду.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Для правильного решения задачи на этом шаге необходимо внести правки. Напоминаю, что проект не может быть принят, без их отработки.
# </div>
#
# Для продуктивной работы прошу: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом**
# Мне будет легче отследить изменения, если ты тоже выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
#
# Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самостоятельно найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку.

# %% [markdown]
# # Исследовательский анализ данных сервиса Яндекс Афиша
#
# - Автор: Сенникова Алёна
# - Дата: 18.10.2025
#
# ## Цель и задачи
#
# **Цель:** Провести исследовательский анализ данных сервиса **Яндекс Афиша**, чтобы выявить причины, по которым **осенью 2024 года увеличилось количество заказов**, но при этом **средняя стоимость заказа снизилась**.
# Также необходимо **проверить гипотезы** о различиях в поведении пользователей мобильных и стационарных устройств.
#
# **Задачи:**
# 1. Загрузить данные и познакомиться с их содержимым.
# 2. Провести предобработку данных.
# 3. Провести исследовательский анализ данных:
#     - изучить данные более детально;
#     - изучить взаимосвязь данных в столбце `Сhurn` с другими данными.
# 4. Сформулировать выводы по проведённому анализу.
#
# 1. Загрузить данные и ознакомиться с их содержимым.
# 2. Провести предобработку данных и подготовить их к исследованию.
# 3. Выполнить исследовательский анализ данных:
#    - изучить сезонные изменения пользовательской активности;
#    - выявить динамику заказов, популярность категорий событий и партнёров;
#    - исследовать различия между пользователями мобильных и стационарных устройств.
# 4. Проверить статистические гипотезы о различиях в поведении пользователей разных устройств.
# 5. Сформулировать общий вывод и предложить рекомендации.
#
#
#
# ## Данные
#
# Для анализа поступили данные о клиентах банка «Метанпром». Данные состоят из двух датасетов:
#
# - `final_tickets_orders_df.csv` — данные обо всех заказах билетов, совершённых с разных типов устройств;
# - `final_tickets_events_df.csv` — информация о событиях, включая город, регион, организаторов и площадки;
# - `final_tickets_tenge_df.csv` — данные о курсе тенге к российскому рублю.
#
#
# ### Описание датасета `final_tickets_orders_df.csv`
#
# - `order_id` — уникальный идентификатор заказа
# - `user_id` — уникальный идентификатор пользователя
# - `created_dt_msk` — дата создания заказа
# - `created_ts_msk` — дата и время создания заказа
# - `event_id` — идентификатор мероприятия
# - `cinema_circuit` — сеть кинотеатров
# - `age_limit` — возрастное ограничение мероприятия
# - `currency_code` — валюта оплаты (`rub`, `kzt`)
# - `device_type_canonical` — тип устройства (`mobile`, `desktop`)
# - `revenue` — выручка от заказа
# - `service_name` — билетный оператор
# - `tickets_count` — количество купленных билетов
# - `total` — общая сумма заказа
# - `days_since_prev` — количество дней с предыдущей покупки пользователя
#
# ### Описание датасета `final_tickets_events_df.csv`
#
# - `event_id` — уникальный идентификатор мероприятия
# - `event_name` — название мероприятия
# - `event_type_description` — описание типа мероприятия
# - `event_type_main` — основной тип мероприятия
# - `organizers` — организаторы мероприятия
# - `region_name` — регион проведения
# - `city_name` — город проведения
# - `venue_id` — идентификатор площадки
# - `venue_name` — название площадки
# - `venue_address` — адрес площадки
#
# ### Описание датасета `final_tickets_tenge_df.csv`
#
# - `nominal` — номинал(100 тенге)
# - `data` — дата
# - `curs` — курс тенге к рублю
# - `cdx` — обозначение валюты(`kzt`)
#
# ## Структура проекта
#
# 1. Загрузка данных и знакомство с ними
# 2. Предобработка и очистка данных
#     - Преобразование валют и создание новых признаков
# 4. Исследовательский анализ данных
#     - Анализ сезонных изменений заказов
#     - Изучение активности пользователей осенью
#     - Анализ популярных событий, регионов и партнёров
# 9. Проверка статистических гипотез
# 10. Общие выводы и рекомендации
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Отличное введение в проект! Сформулировано все наиболее важное для понимания твоим будущим работодателем всех ключевых моментов проекта.

# %% [markdown]
# ## Загрузка данных и знакомство с ними
#
# Начнём с загрузки необходимых библиотек и датасетов:
# `final_tickets_orders_df.csv`, `final_tickets_events_df.csv` и `final_tickets_tenge_df.csv`.
#
# Для анализа будем использовать **pandas** для работы с таблицами, **matplotlib** и **seaborn** для визуализации, а также **numpy** и **scipy** для последующих расчётов и статистических тестов.
#
# Данные сохраним в трёх переменных: `orders_df`, `events_df`, `tenge_df`.

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st

# %%
# Загружаем датасеты
orders_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_orders_df.csv')
events_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_events_df.csv')
tenge_df = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %% [markdown]
# Познакомимся с данными датасета `final_tickets_orders_df.csv` — выведем первые строки методом `head()` и информацию методом `info()`.

# %%
# Просмотр первых строк orders_df
orders_df.head()
# Out:
#    order_id          user_id created_dt_msk       created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20  2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23  2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06  2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13  2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04  2024-10-04 22:33:15    509453
#
#   cinema_circuit  age_limit currency_code device_type_canonical  revenue  \
# 0            нет         16           rub                mobile  1521.94
# 1            нет          0           rub                mobile   289.45
# 2            нет          0           rub                mobile  1258.57
# 3            нет          0           rub                mobile     8.49
# 4            нет         18           rub                mobile  1390.41
#
#          service_name  tickets_count     total  days_since_prev
# ...

# %%
# Общая информация о таблице orders_df
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290849 entries, 0 to 290848
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               290849 non-null  int64
#  1   user_id                290849 non-null  object
#  2   created_dt_msk         290849 non-null  object
#  3   created_ts_msk         290849 non-null  object
#  4   event_id               290849 non-null  int64
#  5   cinema_circuit         290849 non-null  object
#  6   age_limit              290849 non-null  int64
#  7   currency_code          290849 non-null  object
#  8   device_type_canonical  290849 non-null  object
#  9   revenue                290849 non-null  float64
#  10  service_name           290849 non-null  object
#  11  tickets_count          290849 non-null  int64
#  12  total                  290849 non-null  float64
#  13  days_since_prev        268909 non-null  float64
# ...

# %% [markdown]
# Датасет `final_tickets_orders_df.csv` содержит **290 849 строк** и **14 столбцов** с информацией обо всех заказах билетов, совершённых с мобильных и стационарных устройств.
#
# После первичного анализа данных можно сделать следующие выводы:
# - Временные признаки(`created_dt_msk`, `created_ts_msk`) пока имеют тип `object`, хотя должны быть в формате `datetime64`. Эти поля нужно будет преобразовать в формат даты и времени на этапе предобработки для корректного анализа динамики и сезонности.
# - Числовые признаки (`revenue`, `tickets_count`, `total`, `days_since_prev`) имеют корректные типы данных (`float64` и `int64`).
# - Категориальные признаки (`device_type_canonical`, `currency_code`, `service_name`, `cinema_circuit`) представлены строками (`object`), что соответствует содержимому.
# - Пропуски присутствуют только в столбце `days_since_prev` — это ожидаемо, так как для пользователей с первой покупкой интервал не определяется.
# - Все остальные столбцы полностью заполнены.
# - Названия столбцов уже приведены к формату snake_case.
# - Признаки `revenue` и `total` заданы в разных валютах (`rub` и `kzt`) — на этапе предобработки потребуется привести всё к рублям.
# - Признак `device_type_canonical` содержит значения `mobile` и `desktop`, что позволит сегментировать пользователей по типу устройства.
#
# Теперь познакомимся с данными второго датасета — `final_tickets_events_df.csv`.

# %%
# Просмотр первых строк events_df
events_df.head()
# Out:
#    event_id                            event_name event_type_description  \
# 0      4436  e4f26fba-da77-4c61-928a-6c3e434d793f              спектакль
# 1      5785  5cc08a60-fdea-4186-9bb2-bffc3603fb77              спектакль
# 2      8817  8e379a89-3a10-4811-ba06-ec22ebebe989              спектакль
# 3      8849  682e3129-6a32-4952-9d8a-ef7f60d4c247              спектакль
# 4      8850  d6e99176-c77f-4af0-9222-07c571f6c624              спектакль
#
#   event_type_main organizers           region_name   city_name  city_id  \
# 0           театр      №4893  Североярская область      Озёрск        2
# 1           театр      №1931  Светополянский округ   Глиноград       54
# 2           театр      №4896  Североярская область      Озёрск        2
# 3           театр      №4960    Каменевский регион  Глиногорск      213
# 4           театр      №4770      Лесодальний край  Родниковец       55
#
#    venue_id                               venue_name             venue_address
# ...

# %%
# Общая информация о таблице events_df
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22427 entries, 0 to 22426
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                22427 non-null  int64
#  1   event_name              22427 non-null  object
#  2   event_type_description  22427 non-null  object
#  3   event_type_main         22427 non-null  object
#  4   organizers              22427 non-null  object
#  5   region_name             22427 non-null  object
#  6   city_name               22427 non-null  object
#  7   city_id                 22427 non-null  int64
#  8   venue_id                22427 non-null  int64
#  9   venue_name              22427 non-null  object
#  10  venue_address           22427 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.9+ MB

# %% [markdown]
# Датасет `final_tickets_events_df.csv` содержит **22 427 строк** и **11 столбцов** с информацией о мероприятиях, организаторах и площадках проведения.
#
# По аналогии с предыдущим датасетом можно отметить, что:
#
# - Формат данных корректен, все поля заполнены — пропусков в таблице нет.
# - Типы данных соответствуют содержимому:
#   - категориальные признаки (`event_type_main`, `event_type_description`, `region_name`, `city_name`, `venue_name`, `venue_address`, `organizers`) имеют тип `object`;
#   - идентификаторы (`event_id`, `city_id`, `venue_id`) имеют числовой тип `int64`.
# - Столбцы `region_name` и `city_name` содержат географическую информацию, пригодную для регионального анализа популярности событий.
# - `organizers` и `venue_name` могут использоваться для выявления топовых организаторов и площадок по числу заказов и выручке.
# - Названия столбцов уже приведены к удобному формату snake_case.
#
# В таблице нет пропусков, структура данных корректна, и можно объединять с таблицей заказов `orders_df` по ключу `event_id`.
#
# Теперь изучим третий датасет — `final_tickets_tenge_df.csv`.

# %%
# Просмотр первых строк tenge_df
tenge_df.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
# Общая информация о таблице tenge_df
tenge_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %% [markdown]
# Датасет `final_tickets_tenge_df.csv` содержит **357 строк** и **4 столбца** с ежедневной информацией о курсе казахстанского тенге к российскому рублю за 2024 год.
#
# По результатам анализа структуры:
# - Пропусков в таблице нет.
# - Типы данных:
#   - `data` — тип `object`, необходимо преобразовать в `datetime64` для корректного объединения по дате
#   - `nominal` — номинал, всегда равен 100
#   - `curs` — курс тенге к рублю, тип `float64`
#   - `cdx` — обозначение валюты, строковый тип
#
# После изменения типа данных столбца `data` таблица будет готова для объединения с заказами по дате и валюте.
#
# Все три датасета успешно загружены и соответствуют описанию.
# Пропуски обнаружены только в столбце `days_since_prev`, а временные признаки и даты требуют преобразования в формат `datetime`.
# На следующем этапе данные будут очищены, объединены и приведены к единой валюте.
#
# ---

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Хороший выбор методов для первичной оценки данных и очень точные первые выводы, так держать!

# %% [markdown]
# ## Предобработка и очистка данных
#
# ### Проверяем наличие пропусков в данных
#
# При первичном знакомстве с данными было отмечено, что пропуски могут быть только в столбце `days_since_prev`. Узнаем абсолютное и относительное количество пропусков в этом столбце.

# %%
# Применяем метод isna() 
orders_df['days_since_prev'].isna().sum()
# Out:
# 21940

# %%
# Подсчитываем долю строк с пропусками
orders_df['days_since_prev'].isna().mean().round(3)
# Out:
# 0.075

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Отличная идея изучать, не только количество, но и доли пропусков! Предложу как  сделать это немного лаконичнее: использовать метод `mean()` после вызова `isna()`

# %% [markdown]
# <div class="alert alert-info"> Спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Рад помочь советом!

# %% [markdown]
# Результаты показывают, что пропуски в столбце days_since_prev составляют примерно **7,5% строк**.
# Это логично, так как для пользователей с первой покупкой интервал до предыдущего заказа не может быть рассчитан.

# %% [markdown]
# ### Проверяем корректность категориальных значений
#
# Изучим уникальные значения в ключевых категориальных столбцах и убедимся, что нет ошибок и скрытых пропусков.

# %%
# Проверим уникальные значения
for column in ['currency_code', 'device_type_canonical', 'cinema_circuit', 'service_name']:
    print(orders_df[column].unique(), '\n')
# Out:
# ['rub' 'kzt']
#
# ['mobile' 'desktop']
#
# ['нет' 'Другое' 'Киномакс' 'КиноСити' 'Москино' 'ЦентрФильм']
#
# ['Край билетов' 'Мой билет' 'За билетом!' 'Лови билет!'
#  'Билеты без проблем' 'Облачко' 'Лучшие билеты' 'Прачечная' 'Быстробилет'
#  'Дом культуры' 'Весь в билетах' 'Билеты в руки' 'Тебе билет!'
#  'Show_ticket' 'Городской дом культуры' 'Яблоко' 'Билет по телефону'
#  'Выступления.ру' 'Росбилет' 'Шоу начинается!' 'Мир касс' 'Восьмёрка'
#  'Телебилет' 'Crazy ticket!' 'Реестр' 'Быстрый кассир' 'КарандашРУ'
#  'Радио ticket' 'Дырокол' 'Вперёд!' 'Кино билет' 'Цвет и билет' 'Зе Бест!'
#  'Тех билет' 'Лимоны' 'Билеты в интернете']

# %%
# Проверим уникальные значения
for column in ['event_type_main', 'region_name', 'city_name']:
    print(events_df[column].sort_values().unique(), '\n')
# Out:
# ['выставки' 'другое' 'концерты' 'спорт' 'стендап' 'театр' 'ёлки']
#
# ['Белоярская область' 'Берестовский округ' 'Берёзовская область'
#  'Боровлянский край' 'Верховинская область' 'Верхозёрский край'
#  'Верхоречная область' 'Ветренский регион' 'Вишнёвский край'
#  'Глиногорская область' 'Голубевский округ' 'Горицветская область'
#  'Горноземский регион' 'Горностепной регион' 'Дальнеземская область'
#  'Дальнезорский край' 'Дубравная область' 'Залесский край'
#  'Заречная область' 'Зеленоградский округ' 'Златопольский округ'
#  'Золотоключевской край' 'Зоринский регион' 'Каменевский регион'
#  'Каменичская область' 'Каменноозёрный край' 'Каменноярский край'
#  'Каменополянский округ' 'Ключеводский округ' 'Кристаловская область'
#  'Кристальная область' 'Крутоводская область' 'Крутоводский регион'
#  'Лесноярский край' 'Лесодальний край' 'Лесополянская область'
#  'Лесостепной край' 'Лесоярская область' 'Луговая область'
# ...

# %% [markdown]
# Все значения категориальных признаков корректны и не требуют исправления.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Умелое применение цикла для ананлиза однотипных параметров

# %% [markdown]
# ###  Проверяем количественные данные и выбросы
#
# Для анализа выберем ключевые числовые показатели — `revenue` и `tickets_count`.
#
# Так как выручка `revenue` представлена в разных валютах (`rub` и `kzt`), проанализируем числовые признаки отдельно для каждого валютного сегмента. Это позволит корректно выявить выбросы и оценить типичный уровень выручки в каждой группе.

# %%
# Рассмотрим статистику по заказам в рублях
orders_df[orders_df['currency_code'] == 'rub'][['revenue', 'tickets_count']].describe()
# Out:
#              revenue  tickets_count
# count  285780.000000  285780.000000
# mean      547.568333       2.754077
# std       871.524559       1.171419
# min       -90.760000       1.000000
# 25%       113.827500       2.000000
# 50%       346.100000       3.000000
# 75%       791.700000       4.000000
# max     81174.540000      57.000000

# %%
# Рассмотрим статистику по заказам в тенге
orders_df[orders_df['currency_code'] == 'kzt'][['revenue', 'tickets_count']].describe()
# Out:
#             revenue  tickets_count
# count   5069.000000    5069.000000
# mean    4995.206767       2.762872
# std     4916.752776       1.115558
# min        0.000000       1.000000
# 25%      518.100000       2.000000
# 50%     3698.830000       3.000000
# 75%     7397.660000       4.000000
# max    26425.860000       6.000000

# %% [markdown]
# В выборке преобладают заказы в рублях.
# Средняя выручка по заказам в рублях составляет **548**, при медиане **346**, что говорит о сильной асимметрии распределения и наличии выбросов — максимальные значения превышают **80 000**.
#
# В заказах, оплаченных в тенге, средняя выручка составляет **5000**, при медиане **3700**, разброс значений также значительный, но выбросы менее выражены.
#
# В обоих случаях количество билетов стабильно — медианное значение **3**, что свидетельствует о типичном размере заказа.
#
# Далее визуализируем распределения, чтобы убедиться в наличии выбросов и форме распределения данных.

# %%
# Визуализируем распределения выручки отдельно по валютам
fig, axes = plt.subplots(2, 2, figsize=(12, 7)) # fig - общая фигура, axes - массив подграфиков

sns.histplot(data=orders_df[orders_df['currency_code'] == 'rub'], x='revenue', bins=50, ax=axes[0,0])
axes[0,0].set_title('Распределение выручки (RUB)')

sns.histplot(data=orders_df[orders_df['currency_code'] == 'kzt'], x='revenue', bins=50, ax=axes[0,1])
axes[0,1].set_title('Распределение выручки (KZT)')

sns.boxplot(data=orders_df[orders_df['currency_code'] == 'rub'], y='revenue', ax=axes[1,0])
axes[1,0].set_title('Диаграмма размаха (RUB)')

sns.boxplot(data=orders_df[orders_df['currency_code'] == 'kzt'], y='revenue', ax=axes[1,1])
axes[1,1].set_title('Диаграмма размаха (KZT)')

plt.tight_layout() # автоматически подбирает расстояния между подграфиками
plt.show()

# %% [markdown]
# Распределение выручки в рублях резко скошено вправо — подавляющее большинство заказов имеет выручку **до 2000**, однако встречаются заказы с выручкой более **70 000–80 000**, что подтверждает наличие выбросов.
#
# Диаграмма размаха показывает множество точек-аномалий, расположенных за пределами межквартильного диапазона.
#
# Распределение в тенге также несимметрично, но «хвост» менее длинный. Основная масса заказов сосредоточена в диапазоне **0–10  000**, при медиане около **3700**. Выбросы присутствуют и здесь, но в меньшем количестве.
#
# Таким образом, обе валютные группы содержат **аномальные значения** выручки, особенно в рублях.
#
# Перед расчётом средних показателей отберем значения **по 99-му процентилю** и удалим отрицательные значения для корректного анализа.

# %%
# Удаляем отрицательные значения
orders_df.loc[orders_df['revenue'] < 0, 'revenue'] = np.nan

# Рассчитаем 99-й процентиль для каждой валюты
q99 = orders_df.groupby('currency_code')['revenue'].quantile(0.99)

# Ограничим значения revenue
orders_df = orders_df[orders_df['revenue'] <= orders_df['currency_code'].map(q99)]

# %% [markdown]
# После очистки данные по выручке стали более сбалансированными, лучше отражают типичные заказы пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Алёна, все графики отлично оформлены, есть и заголовки и подписи осей. По обоснованию решения все логично. С блоком анализа выбросов ты справилась прекрасно

# %% [markdown]
# ### Проверим наличие дубликатов
#
# Проверим, есть ли повторяющиеся строки — как полные, так и неявные

# %%
# Количество полных дубликатов
orders_df.duplicated().sum()
# Out:
# 0

# %%
# Проверим неявные дубликаты без учёта order_id
orders_df.duplicated(subset=['user_id', 'event_id', 'created_ts_msk', 'tickets_count', 'total']).sum()
# Out:
# 43

# %%
# Отбираем неявные дубликаты без учёта order_id
duplicates = orders_df.duplicated(subset=['user_id', 'event_id', 'created_ts_msk',
                                          'tickets_count', 'total'], keep = False)

# %% [markdown]
# Полных дубликатов строк не обнаружено, однако есть **43 неявных дубликата** без учёта order_id.

# %%
# Посмотрим первые несколько строк с дубликатами
orders_df.loc[duplicates, ['user_id', 'event_id', 'created_ts_msk',
                           'tickets_count', 'total']].sort_values(by = 'created_ts_msk').head(10)
# Out:
#                 user_id  event_id       created_ts_msk  tickets_count  \
# 232676  c7a762e320f0def    538926  2024-06-19 11:07:59              3
# 232673  c7a762e320f0def    538926  2024-06-19 11:07:59              3
# 285618  fd4d47438ebb946    489843  2024-06-19 15:40:50              3
# 285617  fd4d47438ebb946    489843  2024-06-19 15:40:50              3
# 285622  fd4d47438ebb946    489843  2024-06-19 15:40:56              4
# 285615  fd4d47438ebb946    489843  2024-06-19 15:40:56              4
# 285614  fd4d47438ebb946    489843  2024-06-19 15:40:56              4
# 285612  fd4d47438ebb946    489843  2024-06-19 15:40:56              3
# 285619  fd4d47438ebb946    489843  2024-06-19 15:40:56              3
# 176439  8f95286aa5fd8d7    244875  2024-06-20 10:57:19              3
#
#            total
# 232676      0.00
# 232673      0.00
# 285618  10995.23
# 285617  10995.23
# 285622  14660.31
# 285615  14660.31
# 285614  14660.31
# 285612  10995.23
# 285619  10995.23
# ...

# %% [markdown]
# Повторяющиеся записи принадлежат одним и тем же пользователям, имеют одинаковую дату и параметры заказа.
# Скорее всего причина техническаая, например, повторная фиксация одного и того же заказа в момент выгрузки данных.
#
# Если оставить такие строки, то общая выручка и количество заказов будут завышены. Необходимо **удалить дубликаты**.

# %%
# Удалим неявные дубликаты
orders_df = orders_df.drop_duplicates(subset=['user_id', 'event_id', 'created_ts_msk',
                                              'tickets_count', 'total'])

# %%
# Проверим, что строки удалены
orders_df.shape
# Out:
# (287596, 14)

# %%
# Проверим уникальность идентификатора события второго датасета
events_df['event_id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# В результате проверки:
# - Полных дубликатов в таблицах не обнаружено.
# - В таблице `orders_df` выявлено **43 неявных дубликата** по признакам пользователя, события, даты и суммы заказа — они были удалены.
# - В таблице `events_df` дубликаты отсутствуют — каждая запись уникальна по `event_id`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Очень качественная работа с "дублями" и полезное решение взглянуть на эти строки, чтобы принять однозначное решение

# %% [markdown]
# ### Проводим преобразования типов данных и создаём новые столбцы
#
# Приведём временные признаки к типу datetime64 и выполним понижение разрядности числовых столбцов для оптимизации.
#
# Создадим дополнительные столбцы, необходимые для анализа.

# %%
# Преобразуем временные признаки
orders_df['created_dt_msk'] = pd.to_datetime(orders_df['created_dt_msk'])
orders_df['created_ts_msk'] = pd.to_datetime(orders_df['created_ts_msk'])

# Применяем понижение разрядности
for column in ['order_id', 'event_id', 'age_limit', 'tickets_count']:
    orders_df[column] = pd.to_numeric(orders_df[column], downcast = 'integer')

for column in ['revenue', 'total', 'days_since_prev']:
    orders_df[column] = pd.to_numeric(orders_df[column], downcast = 'float')

# Проверяем типы данных
orders_df.dtypes
# Out:
# order_id                          int32
# user_id                          object
# created_dt_msk           datetime64[ns]
# created_ts_msk           datetime64[ns]
# event_id                          int32
# cinema_circuit                   object
# age_limit                          int8
# currency_code                    object
# device_type_canonical            object
# revenue                         float32
# service_name                     object
# tickets_count                      int8
# total                           float32
# days_since_prev                 float32
# dtype: object

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b> Полезная привычка строго приводить даты. А еще можно рассмотреть вариант понижения разрядности для отдельных столбцов. Да, на наших данных большого эффекта это не даст, но в реальной практике это иногда бывает полезным

# %% [markdown]
# <div class="alert alert-info"> Спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Практичное решение

# %% [markdown]
# Создадим новые признаки:
#
# `revenue_rub` — выручка в рублях
#
# `one_ticket_revenue_rub` — выручка с одного билета
#
# `month` — месяц оформления заказа
#
# `season` — сезон года.

# %% [markdown]
# Преобразуем дату в таблице `tenge_df` и рассчитаем курс перевода тенге в рубли (`rub_per_kzt`).

# %%
# Преобразуем дату и рассчитаем курс за 1 тенге
tenge_df['data'] = pd.to_datetime(tenge_df['data'])
tenge_df['rub_per_kzt'] = tenge_df['curs'] / tenge_df['nominal']

# Проверим результат
tenge_df.head()
# Out:
#         data  nominal     curs  cdx  rub_per_kzt
# 0 2024-01-10      100  19.9391  kzt     0.199391
# 1 2024-01-11      100  19.7255  kzt     0.197255
# 2 2024-01-12      100  19.5839  kzt     0.195839
# 3 2024-01-13      100  19.4501  kzt     0.194501
# 4 2024-01-14      100  19.4501  kzt     0.194501

# %% [markdown]
# Объединим таблицы заказов и курсов валют по дате.

# %%
# Объединяем таблицы
orders_df = orders_df.merge(
    tenge_df[['data', 'rub_per_kzt']],
    left_on = 'created_dt_msk', right_on = 'data',
    how='left'
)

# Проверим результат
orders_df.head()
# Out:
#    order_id          user_id created_dt_msk      created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20 2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23 2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06 2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13 2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04 2024-10-04 22:33:15    509453
#
#   cinema_circuit  age_limit currency_code device_type_canonical      revenue  \
# 0            нет         16           rub                mobile  1521.939941
# 1            нет          0           rub                mobile   289.450012
# 2            нет          0           rub                mobile  1258.569946
# 3            нет          0           rub                mobile     8.490000
# 4            нет         18           rub                mobile  1390.410034
#
# ...

# %% [markdown]
# Создадим новый столбец `revenue_rub`, где приведём всю выручку к российским рублям.

# %%
# Функция для конвертации выручки в рубли
def to_rub(revenue, currency, rate):
    if currency == 'rub':
        return revenue
    elif currency == 'kzt':
        return revenue * rate

# %%
# Применяем функцию для перевода выручки в рубли
orders_df['revenue_rub'] = orders_df.apply(lambda x: to_rub(x['revenue'], x['currency_code'], x['rub_per_kzt']), axis=1)

# Проверим результат
orders_df[orders_df['currency_code'] == 'kzt'].head()
# Out:
#      order_id          user_id created_dt_msk      created_ts_msk  event_id  \
# 73    7850214  0033403583a55ed     2024-09-17 2024-09-17 16:52:06    559919
# 91    8634925  0040e12d70fae81     2024-09-02 2024-09-02 19:49:14    559476
# 98    7625522  0054b38b2653e6e     2024-09-09 2024-09-09 18:06:04    559582
# 464   5227657  01370a0e9c1a7d5     2024-06-04 2024-06-04 13:28:17    533803
# 465   2229782  01370a0e9c1a7d5     2024-06-04 2024-06-04 13:17:35    533803
#
#     cinema_circuit  age_limit currency_code device_type_canonical  \
# 73             нет          6           kzt                mobile
# 91             нет          6           kzt               desktop
# 98             нет          6           kzt                mobile
# 464            нет         16           kzt               desktop
# 465            нет         16           kzt                mobile
#
#          revenue        service_name  tickets_count          total  \
# ...

# %% [markdown]
# Добавим показатель `one_ticket_revenue_rub` — выручка за один билет.

# %%
# Выручка за один билет
orders_df['one_ticket_revenue_rub'] = orders_df['revenue_rub'] / orders_df['tickets_count']

# Проверим результат
orders_df.head(10)
# Out:
#    order_id          user_id created_dt_msk      created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20 2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23 2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06 2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13 2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04 2024-10-04 22:33:15    509453
# 5   2613713  000898990054619     2024-10-23 2024-10-23 15:12:00    500862
# 6   6636941  00096d1f542ab2b     2024-08-15 2024-08-15 16:48:48    201953
# 7   4657981  000a55a418c128c     2024-09-29 2024-09-29 19:39:12    265857
# 8   4657952  000a55a418c128c     2024-10-15 2024-10-15 10:29:04    271579
# 9   6818017  000cf0659a9f40f     2024-06-20 2024-06-20 10:35:26    516728
#
#   cinema_circuit  age_limit currency_code device_type_canonical      revenue  \
# ...

# %% [markdown]
# Выделим месяц оформления заказа в отдельный столбец `month`.

# %%
# Создаём столбец с месяцем оформления заказа
orders_df['month'] = orders_df['created_dt_msk'].dt.month

# Проверим результат
orders_df['month'].unique()
# Out:
# array([ 8,  7, 10,  9,  6])

# %% [markdown]
# Создадим столбец `season`, отражающий сезон, в который был оформлен заказ: лето, осень, зима или весна.

# %%
# Функция для определения сезона по месяцу
def month_to_season(month):
    if month in [12, 1, 2]:
        return 'зима'
    elif month in [3, 4, 5]:
        return 'весна'
    elif month in [6, 7, 8]:
        return 'лето'
    elif month in [9, 10, 11]:
        return 'осень'

# %%
# Применим функцию
orders_df['season'] = orders_df['month'].apply(month_to_season)

# Проверим результат
orders_df.head(10)
# Out:
#    order_id          user_id created_dt_msk      created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20 2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23 2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06 2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13 2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04 2024-10-04 22:33:15    509453
# 5   2613713  000898990054619     2024-10-23 2024-10-23 15:12:00    500862
# 6   6636941  00096d1f542ab2b     2024-08-15 2024-08-15 16:48:48    201953
# 7   4657981  000a55a418c128c     2024-09-29 2024-09-29 19:39:12    265857
# 8   4657952  000a55a418c128c     2024-10-15 2024-10-15 10:29:04    271579
# 9   6818017  000cf0659a9f40f     2024-06-20 2024-06-20 10:35:26    516728
#
#   cinema_circuit  age_limit currency_code device_type_canonical      revenue  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Новые столбцы созданы и в очередной раз ты не забыла проконтролировать результаты, это очень полезно и поможет пользователям лучше понимать какие подготовленные данные ты будешь ананлизировать в следущей главе

# %% [markdown]
# Теперь объединеним данные с таблицей событий `events_df` - это позволит дополнить заказы информацией о типах мероприятий, регионах и площадках.

# %%
# Объединяем заказы с таблицей событий
df = orders_df.merge(events_df, on = 'event_id', how = 'inner')

# Проверим структуру
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 287358 entries, 0 to 287357
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                287358 non-null  int32
#  1   user_id                 287358 non-null  object
#  2   created_dt_msk          287358 non-null  datetime64[ns]
#  3   created_ts_msk          287358 non-null  datetime64[ns]
#  4   event_id                287358 non-null  int32
#  5   cinema_circuit          287358 non-null  object
#  6   age_limit               287358 non-null  int8
#  7   currency_code           287358 non-null  object
#  8   device_type_canonical   287358 non-null  object
#  9   revenue                 287358 non-null  float32
#  10  service_name            287358 non-null  object
#  11  tickets_count           287358 non-null  int8
#  12  total                   287358 non-null  float32
# ...

# %% [markdown]
# В итоговом датафрейме — **287 358** строк и **30** столбцов.
# Это соответствует количеству заказов, которые имеют корректное соответствие в таблице событий.
# Таким образом, из общего числа заказов 290 849 в анализ было включено более 95% предобработанных данных.

# %% [markdown]
# ### Промежуточный вывод по этапу предобработки
#
# В ходе предобработки данных были выполнены следующие действия:
#
# - Проверены пропуски: пропуски остались только в столбце `days_since_prev`, что объясняется особенностью первой покупки пользователя.
# - Изучены категориальные признаки: ошибки и скрытые пропуски не обнаружены.
# - Проведён анализ количественных данных, устранены отрицательные значения и выбросы в `revenue`.
# - Проверены дубликаты: найдено 42 неявных дубликата, которые были удалены.
# - Таблица `events_df` проверена на корректность — дубликаты отсутствуют.
# - Выполнено преобразование временных признаков `created_dt_msk`, `created_ts_msk` в тип `datetime64`.
# - Все заказы приведены к единой валюте (рубли) — создан признак `revenue_rub`.
# - Добавлены новые признаки:
#   - `one_ticket_revenue_rub` — выручка с одного билета;
#   - `month` — месяц оформления заказа;
#   - `season` — сезон (зима, весна, лето, осень).
# - Таблицы объединены с типом соединения `inner join`, чтобы оставить только релевантные заказы с корректными событиями.
#
# Итоговый датафрейм `df` содержит **287 358 строк** и **30 признаков**, включая все необходимые поля.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Хочу отметить, что этап предобработки в целом выполнен последовательно и качественно, все основные шаги преобразований выполнены и даны понятные и лаконичные промежуточные выводы

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ распределения заказов по сегментам и их сезонные изменения
#
# Проанализируем сезонную динамику заказов на основе данных за 2024 год.
# Изучим распределение заказов по месяцам и категориям:
#
# - тип мероприятия (`event_type_main`)
# - тип устройства (`device_type_canonical`)
# - возрастная категория (`age_limit`)
#
# Также рассмотрим изменение выручки с одного билета между летним и осенним сезонами.

# %%
# Рассчитаем количество заказов по месяцам
users_per_month = df.groupby('month')['order_id'].nunique()

users_per_month
# Out:
# month
# 6     34056
# 7     40358
# 8     44529
# 9     69262
# 10    99153
# Name: order_id, dtype: int64

# %%
# Визуализируем динамику заказов по месяцам
plt.figure(figsize=(10, 4))
users_per_month.plot(kind='bar')
plt.title('Количество заказов по месяцам за 2024 год')
plt.xlabel('Месяц')
plt.ylabel('Количество заказов')
plt.xticks(rotation=0) # поворачивает подписи на оси X
plt.show()

# %% [markdown]
# Результаты показывают, что с июня по октябрь количество заказов **постепенно увеличивается**,  что указывает на сезонный рост пользовательской активности осенью.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>  Общий тренд зафиксирован

# %% [markdown]
# Сравненим летний и осенний периоды по категориям мероприятий.

# %%
# Фильтруем данные по сезонам
summer_df = df[df['season'] == 'лето'].copy()
autumn_df = df[df['season'] == 'осень'].copy()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Признаки лето и осень ужу выделены тобой выше можно сразу брать их, а не по месяцам, так немного лаконичнее

# %% [markdown]
# <div class="alert alert-info"> Забыла об этом, спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Всегда пожалуйста)

# %%
# Рассчитаем долю заказов по типу мероприятия
summer_events = summer_df['event_type_main'].value_counts(normalize=True)
autumn_events = autumn_df['event_type_main'].value_counts(normalize=True)

# Объединим летние и осенние доли в один датафрейм
season_event = pd.DataFrame({
    'Лето': summer_events,
    'Осень': autumn_events
}).fillna(0).round(3).sort_values(by = ['Лето', 'Осень'], ascending = False)

season_event
# Out:
#            Лето  Осень
# концерты  0.427  0.373
# другое    0.271  0.196
# театр     0.201  0.254
# стендап   0.053  0.041
# спорт     0.025  0.112
# выставки  0.020  0.014
# ёлки      0.002  0.010

# %%
# Визуализируем сравнение распределений
season_event.plot(kind='bar', figsize=(8, 4))
plt.title('Сравнение распределений заказов по типам мероприятий')
plt.xlabel('Тип мероприятия')
plt.ylabel('Доля заказов')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Удачный выбор типа визуализации и оформлено все образцово

# %% [markdown]
# Распределение заказов летом и осенью заметно отличается:
#
#  - Концерты остаются лидером по числу заказов, но их доля снижается с **41% до 36%**.
#
#  - Театр демонстрирует рост интереса — доля заказов увеличивается с **20% до 25%**, что указывает на рост популярности культурных мероприятий в холодный сезон.
#
#  - Спортивные события значительно выросли — **с 2,6% до 11,6%**.
#
#  - Категории «другое» и «стендап» снизили долю заказов.

# %% [markdown]
# Рассмотрим распределение заказов по типу устройства.

# %%
# Рассчитаем долю заказов по типу устройства
summer_devices = summer_df['device_type_canonical'].value_counts(normalize=True)
autumn_devices = autumn_df['device_type_canonical'].value_counts(normalize=True)

# Объединим летние и осенние доли в один датафрейм
season_devices = pd.DataFrame({
    'Лето': summer_devices,
    'Осень': autumn_devices
}).fillna(0).round(3).sort_values(by = ['Лето', 'Осень'], ascending = False)

season_devices
# Out:
#           Лето  Осень
# mobile   0.806  0.796
# desktop  0.194  0.204

# %%
# Визуализируем сравнение распределений
season_devices.plot(kind='bar', figsize=(8, 4))
plt.title('Сравнение распределений заказов по типам устройств')
plt.xlabel('Тип устройства')
plt.ylabel('Доля заказов')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Распределение заказов по типам устройств остаётся стабильным между летом и осенью:
#
#  - Мобильные устройства составляют большинство, формируя **около 80%** всех заказов.
#
#  - Стационарные устройства незначительно увеличили долю — с **19,3% до 20,2%**.

# %% [markdown]
# Посмотрим на распределение заказов по возрастным категориям.

# %%
# Рассчитаем долю заказов по возрастной группе
summer_age = summer_df['age_limit'].value_counts(normalize=True)
autumn_age = autumn_df['age_limit'].value_counts(normalize=True)

# Объединим летние и осенние доли в один датафрейм
season_age = pd.DataFrame({
    'Лето': summer_age,
    'Осень': autumn_age
}).fillna(0).round(3).sort_index()

season_age
# Out:
#      Лето  Осень
# 0   0.179  0.236
# 6   0.182  0.176
# 12  0.205  0.221
# 16  0.284  0.262
# 18  0.150  0.104

# %%
# Визуализируем сравнение распределений
season_age.plot(kind='bar', figsize=(8, 4))
plt.title('Сравнение распределений заказов по возрастному рейтингу')
plt.xlabel('Возрастной рейтинг')
plt.ylabel('Доля заказов')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Доля мероприятий с рейтингом 0+ выросла с **18% до 24%**, что отражает увеличение семейной аудитории.
#
# Категория 12+ также немного выросла - с **20% до 22%**.
#
# Сегмент 16+ остаётся лидером по числу заказов, но его доля слегка снизилась — **с 29% до 26%**.
#
# Доля мероприятий 18+ снизилась — с **15% до 10%**.

# %% [markdown]
# Изучим изменение выручки с продажи одного билета в зависимости от типа мероприятия летом и осенью.

# %%
# Рассчитаем среднюю выручку за один билет летом и осенью
revenue_by_event = df[df['season'].isin(['лето', 'осень'])].groupby(['season', 'event_type_main'])['one_ticket_revenue_rub'].mean().round(2).unstack()

revenue_by_event
# Out:
# event_type_main  выставки  другое  концерты  спорт  стендап   театр    ёлки
# season
# лето                86.74   77.83    304.79  50.81   218.52  214.14  271.44
# осень               91.91   76.48    268.37  50.02   231.12  175.98  229.59

# %%
# Визуализируем сравнение распределений
revenue_by_event.T.plot(kind='bar', figsize=(8, 4)) # транспонируем датафрейм
plt.title('Сравнение распределений средней выручки с одного билета по типам мероприятий')
plt.xlabel('Тип мероприятия')
plt.ylabel('Средняя выручка')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Средняя выручка с одного билета осенью немного снизилась по большинству категорий:
#
#  - Наиболее заметное падение — у концертов **−13%** и театров **−19%**, что может быть связано с изменением формата мероприятий.
#
#  - Стендап показал рост средней цены **+11%**.
#
#  - В категориях выставки и спорт значения остались стабильными.

# %% [markdown]
# **Промежуточный вывод**
#
# С наступлением осени структура спроса заметно изменилась.
#
# Количество заказов выросло, при этом увеличилась доля театров **с 20% до 25%** и спортивных событий **с 3% до 12%**, тогда как концерты снизили долю с **41% до 36%**.
#
# Пользователи по-прежнему совершают около **80% заказов** с мобильных устройств.
#
# По возрастным категориям вырос интерес к семейным и подростковым мероприятиям **(0+, 12+)**, а доля 18+ сократилась.
#
# Средняя **стоимость** билета осенью немного **снизилась** — особенно в театрах и на концертах.
#
# Можно предположить, что осенью наблюдается переход спроса от массовых летних мероприятий к культурным и спортивным событиям с более доступной ценой билета.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>По выводам в разделе  все вполне логично интерпретировано, мы действительно наблюдаем влияние погодных факторов и увеличение числа семейных мероприятий

# %% [markdown]
# ### Осенняя активность пользователей

# %%
# Структура данных за осень
autumn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168415 entries, 14 to 287357
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                168415 non-null  int32
#  1   user_id                 168415 non-null  object
#  2   created_dt_msk          168415 non-null  datetime64[ns]
#  3   created_ts_msk          168415 non-null  datetime64[ns]
#  4   event_id                168415 non-null  int32
#  5   cinema_circuit          168415 non-null  object
#  6   age_limit               168415 non-null  int8
#  7   currency_code           168415 non-null  object
#  8   device_type_canonical   168415 non-null  object
#  9   revenue                 168415 non-null  float32
#  10  service_name            168415 non-null  object
#  11  tickets_count           168415 non-null  int8
#  12  total                   168415 non-null  float32
# ...

# %% [markdown]
# В данных содержится около **168 тысяч** заказов, что достаточно для анализа сезонной активности.

# %% [markdown]
# Создадим сводную таблицу с основными показателями:
#
#  - количество заказов в день
#
#  - количество уникальных пользователей в день - dau
#
#  - среднее число заказов на пользователя
#
#  - средняя выручка с одного билета

# %%
# Формируем показатели по дням
daily_metrics = (
    autumn_df.groupby('created_dt_msk').agg(
        orders_count = ('order_id', 'nunique'),
        dau = ('user_id', 'nunique'),
        avg_ticket_revenue = ('one_ticket_revenue_rub', 'mean')
    ).reset_index()
)

# Добавляем показатель среднее число заказов на пользователя
daily_metrics['orders_per_user'] = daily_metrics['orders_count'] / daily_metrics['dau']

# Проверим результат
daily_metrics.head()
# Out:
#   created_dt_msk  orders_count  dau  avg_ticket_revenue  orders_per_user
# 0     2024-09-01          1327  564          200.168708         2.352837
# 1     2024-09-02          1376  573          190.015637         2.401396
# 2     2024-09-03          5094  777           80.650134         6.555985
# 3     2024-09-04          1760  684          179.363761         2.573099
# 4     2024-09-05          1941  738          189.804479         2.630081

# %% [markdown]
# Построим графики для каждого показателя, чтобы наглядно увидеть сезонную динамику.

# %%
# Размеры графика
fig, axes = plt.subplots(4, 1, figsize=(10, 12))

# Сохраняем названия нужных метрик в список
metrics = ['orders_count', 'dau', 'orders_per_user', 'avg_ticket_revenue']

# Список заголовков графиков
titles = [
    'Динамика общего числа заказов',
    'Динамика количества активных пользователей -DAU',
    'Среднее количество заказов на одного пользователя',
    'Средняя стоимость одного билета'
]

# В цикле рисуем графики и настриваем их оформление
for i, metric in enumerate(metrics):
    axes[i].plot(daily_metrics['created_dt_msk'], daily_metrics[metric])
    axes[i].set_title(titles[i])
    axes[i].set_xlabel('Дата')
    axes[i].grid()

# Автоматически подбираем расстояние между подграфиками
plt.tight_layout()
plt.show()

# %% [markdown]
# В целом осенью наблюдается **рост** пользовательской активности — как по числу заказов, так и по количеству уникальных пользователей DAU. Особенно выраженные пики фиксируются в начале сентября и 1 октября, что, вероятно, связано с проведением массовых мероприятий или акций.
#
# **1 октября** резко выросло количество заказов и активных пользователей, но при этом средняя стоимость билета заметно снизилась. Это может указывать на акции или массовые покупки недорогих билетов.
#
# В остальное время показатели стабильны: в среднем пользователи делали **2–3 заказа в день**, а средняя стоимость билета держалась в диапазоне **180–200 рублей**.
#
# Таким образом, **активность** аудитории осенью **растёт**, но рост обеспечивается в основном за счёт увеличения числа недорогих заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Все метрики рассчитаны и интерпретированы корректно. А предположение про акции действительно однозначно подтверждается совпедением аномальных всплесков средней цены и количества заказов

# %% [markdown]
# Изучим недельную цикличность.

# %%
# Добавляем день недели
autumn_df['weekday'] = autumn_df['created_dt_msk'].dt.day_name()

# Формируем показатели по дням недели
weekday_metrics = (
    autumn_df.groupby('weekday').agg(
        orders = ('order_id', 'nunique'),
        dau = ('user_id', 'nunique'),
        avg_ticket_revenue = ('one_ticket_revenue_rub', 'mean')
    ).reset_index().sort_values('weekday')
)

# Добавляем среднее число заказов на пользователя
weekday_metrics['orders_per_user'] = weekday_metrics['orders'] / weekday_metrics['dau']


# Сортируем дни недели в календарном порядке
weekday_metrics['weekday'] = pd.Categorical( # конструктор, создаёт объект категориального типа
    weekday_metrics['weekday'],
    categories=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'],
    ordered=True # категории упорядочены
)

weekday_metrics = weekday_metrics.sort_values('weekday')

weekday_metrics
# Out:
#      weekday  orders   dau  avg_ticket_revenue  orders_per_user
# 1     Monday   21495  4443          184.368921         4.837947
# 5    Tuesday   31437  4792          140.883145         6.560309
# 6  Wednesday   22854  4814          186.241104         4.747403
# 4   Thursday   27115  4964          178.263573         5.462329
# 0     Friday   24811  4869          185.904336         5.095708
# 2   Saturday   21328  4570          192.408253         4.666958
# 3     Sunday   19375  4393          198.165064         4.410426

# %%
# Визуализируем среднее количество заказов по дням недели
plt.figure(figsize=(8, 4))
plt.bar(weekday_metrics['weekday'], weekday_metrics['orders_per_user'])
plt.title('Среднее количество заказов на пользователя по дням недели')
plt.xlabel('День недели')
plt.ylabel('Заказы на пользователя')
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Дни недели это  дискретные величины и правильнее использовать столбчатую диаграмму

# %% [markdown]
# <div class="alert alert-info"> Спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>

# %% [markdown]
# Анализ недельной активности показал выраженную **цикличность заказов**.
#
# Максимальная активность наблюдается во вторник, когда пользователи оформляют в среднем **6,6 заказа** на человека. После этого показатель постепенно снижается к выходным, достигая минимума в воскресенье - **4,4 заказа** на пользователя.
#
# Пользователи чаще планируют посещения мероприятий **в начале недели**, а к выходным уже совершают меньше заказов.
#
# Средняя стоимость билета остаётся **стабильной** и не зависит существенно от дня недели.

# %% [markdown]
# **Промежуточный вывод**
#
# **Осенью 2024 года** наблюдается **рост** пользовательской активности — количество заказов и уникальных пользователей DAU стабильно увеличивается от сентября к концу октября.
#
# Особенно выделяется **1 октября**, когда зафиксирован **пик заказов и DAU** при одновременном падении средней стоимости билета — вероятно, из-за проведения акций или появления недорогих массовых мероприятий.
#
# **Среднее число заказов** на пользователя держится на уровне **2–3 в день**, а средняя стоимость билета — около **180–200 рублей**, что говорит о стабильной вовлечённости аудитории.
#
# Есть **недельная цикличность**: наибольшая активность приходится на вторник, после чего количество заказов постепенно снижается к выходным, когда пользователи уже используют ранее купленные билеты.
#
# В целом осенью сервис показывает **рост активности и стабильное удержание** пользователей, при этом спрос подвержен чёткой недельной динамике.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Получается в будни многие закупаются к выходным и "ловят" скидки, стоит обязательно учесть это в итоговых выводах и рекомендациях

# %% [markdown]
# ### Популярные события и партнёры
#
# Посмотрим, как осенью распределяются мероприятия и заказы по **регионам** и **партнёрам**, чтобы выделить ключевые источники заказов и выручки.
#
# Для каждого региона посчитаем:
# - уникальное число мероприятий
# - число заказов
# - доли от общего объёма

# %%
# Формируем показатели по регионам
regions_metrics = (
    autumn_df.groupby('region_name').agg(
        events_count = ('event_id','nunique'),
        orders_count = ('order_id','nunique')
    ).sort_values('orders_count', ascending=False)
)

# Добавляем доли
regions_metrics['events_share'] = (regions_metrics['events_count'] / regions_metrics['events_count'].sum()).round(3)
regions_metrics['orders_share'] = (regions_metrics['orders_count'] / regions_metrics['orders_count'].sum()).round(3)

# Проверим результат
regions_metrics.head(10)
# Out:
#                          events_count  orders_count  events_share  \
# region_name
# Каменевский регион               3910         46681         0.247
# Североярская область             2611         20704         0.165
# Медовская область                 368         12041         0.023
# Широковская область               796          8648         0.050
# Озернинский край                  296          7526         0.019
# Светополянский округ              762          4770         0.048
# Серебринская область              456          4467         0.029
# Малиновоярский округ              137          4412         0.009
# Солнечноземская область           402          4197         0.025
# Яблоневская область               431          4196         0.027
#
#                          orders_share
# region_name
# Каменевский регион              0.277
# Североярская область            0.123
# Медовская область               0.071
# Широковская область             0.051
# ...

# %%
# Визуализация топ-10 регионов
plt.figure(figsize=(9,4))
regions_metrics['orders_count'].head(10).plot(kind='bar')
plt.title('Топ-10 регионов по числу заказов')
plt.xlabel('Регион')
plt.ylabel('Количество заказов')
plt.grid(axis='y')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# Лидером по числу заказов и количеству мероприятий стал **Каменевский регион**, на который приходится около **28%** всех заказов и четверть всех событий **24,7%**.
#
# Североярская область занимает второе место - **12,3% заказов**, сохраняя высокую активность пользователей.
#
# Далее с заметным отставанием следуют **Широковская и Светополянский округ** — по **5%** заказов каждая.
#
# Доля большинства остальных регионов невелика — каждый из них занимает **менее 3%**.
#
# Таким образом, рынок сконцентрирован в нескольких ключевых регионах, где сосредоточено основное количество событий и спроса на билеты.

# %% [markdown]
# Для каждого билетного партнёра посчитаем:
# - уникальные мероприятия
# - обработанные заказы
# - суммарную выручку
# - доли от общего объема

# %%
# Формируем показатели по партнёрам
partners_metrics = (
    autumn_df.groupby('service_name').agg(
        events_count = ('event_id','nunique'),
        orders_count = ('order_id','nunique'),
        revenue_rub_sum = ('revenue_rub','sum')
    ).sort_values('revenue_rub_sum', ascending=False)
)

# Добавляем доли
partners_metrics['orders_share'] = (partners_metrics['orders_count'] / partners_metrics['orders_count'].sum()).round(3)
partners_metrics['revenue_share'] = (partners_metrics['revenue_rub_sum'] / partners_metrics['revenue_rub_sum'].sum()).round(3)

# Проверим результат
partners_metrics.head(10)
# Out:
#                     events_count  orders_count  revenue_rub_sum  orders_share  \
# service_name
# Билеты без проблем          2836         32327     1.217260e+07         0.192
# Мой билет                   1005         19415     1.085055e+07         0.115
# Облачко                     1409         15478     1.061105e+07         0.092
# Лови билет!                 3611         25772     1.038196e+07         0.153
# Весь в билетах               599          9415     9.350394e+06         0.056
# Билеты в руки               2457         25642     7.612965e+06         0.152
# Край билетов                 193          2997     3.018373e+06         0.018
# Яблоко                       537          3473     2.763332e+06         0.021
# Прачечная                    728          5798     2.548310e+06         0.034
# Тебе билет!                  858          3759     2.166185e+06         0.022
#
#                     revenue_share
# service_name
# Билеты без проблем          0.149
# ...

# %%
# Визуализация топ-10 партнёров
plt.figure(figsize=(9,4))
(partners_metrics['revenue_rub_sum']/1e6).head(10).plot(kind='bar')
plt.title('Топ-10 партнёров по выручке, млн рублей')
plt.xlabel('Партнёр')
plt.ylabel('Выручка, млн рублей')
plt.grid(axis='y')
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# Основная выручка сосредоточена у **шести ведущих партнёров**:
# - Билеты без проблем
# - Мой билет
# - Облачко
# - Лови билет!
# - Весь в билетах
# - Билеты в руки
#
# Их совокупная доля около **75% общей выручки**, что указывает на высокую концентрацию продаж среди крупных игроков.
#
# Абсолютным лидером остаётся «Билеты без проблем» - **15% выручки**, но «Мой билет», «Облачко», «Лови билет!» и «Весь в билетах» отстают незначительно — их показатели находятся в диапазоне **11–13%** выручки.
# Сервис «Билеты в руки» имеет долю около **9%**, замыкая группу сильнейших партнёров.
#
# Таким образом, рынок партнёров имеет чётко выраженных лидеров, при этом разрыв между ними минимален, что говорит о равномерном распределении спроса между крупными билетными платформами.

# %% [markdown]
# **Промежуточный вывод**
#
# **Осенью 2024 года** заказы и выручка распределены неравномерно:
#
# **Каменевский регион** — лидер по активности: на него приходится около 28% всех заказов и четверть всех событий, что делает его основным центром спроса.
#
# **Североярская область и Широковская область** удерживают второе и третье места с долями 12% и 5% заказов соответственно, занимая ключевые позиции после лидера.
#
# **Остальные** регионы демонстрируют существенно **меньшие объёмы** заказов, но при этом некоторые из них сохраняют заметное разнообразие событий при низкой конверсии в заказ.
#
# Среди партнёров выделяются шесть ключевых, составляющих около **75% выручки**: «Билеты без проблем», «Мой билет», «Облачко», «Лови билет!», «Весь в билетах» и «Билеты в руки».
#
# При этом разрыв между ними минимален — лидеры зарабатывают от **9% до 15%** общей выручки, что указывает на высокую конкуренцию в верхнем сегменте рынка.
#
# Таким образом, рынок билетов характеризуется **высокой концентрацией спроса в отдельных регионах и умеренно сбалансированной конкуренцией среди ведущих партнёров**.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Верно, у нас есть явные лидеры и описать их относительными величинами как это сделала ты идеальное решение

# %% [markdown]
# ## Статистический анализ данных

# %% [markdown]
# ### Гипотеза о среднем количестве заказов
#
# **Гипотеза**: пользователи мобильных устройств совершают в среднем больше заказов на одного пользователя, чем пользователи стационарных устройств.
#
# - Нулевая гипотеза **H₀**: Среднее количество заказов на одного пользователя одинаково для мобильных и стационарных устройств
#
# - Альтернативная гипотеза **H₁**: Среднее количество заказов на одного пользователя выше у мобильных устройств

# %%
# Группируем по типу устройства и пользователю, считаем количество заказов
user_orders = autumn_df.groupby(['user_id', 'device_type_canonical'])['order_id'].count().reset_index()

# Разделяем на две выборки
mobile_orders = user_orders[user_orders['device_type_canonical'] == 'mobile']['order_id']
desktop_orders = user_orders[user_orders['device_type_canonical'] == 'desktop']['order_id']

# Проверим базовые параметры
print(mobile_orders.describe(), '\n\n', desktop_orders.describe())
# Out:
# count    14184.000000
# mean         9.455936
# std         67.978206
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max       4327.000000
# Name: order_id, dtype: float64
#
#  count    4868.000000
# mean        7.044371
# std        35.973532
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         4.000000
# max      1501.000000
# Name: order_id, dtype: float64

# %% [markdown]
# Так как выборки независимы, существенно различаются по размеру (14 184 и 4 868 наблюдений) и имеют неодинаковые дисперсии (стандартное отклонение 67.98 и 35.97), для проверки гипотезы целесообразно использовать двухвыборочный **t-тест Уэлча**.
#
# Он применяется при сравнении средних значений двух групп, не требует равенства дисперсий и устойчив к различию размеров выборок.
#
# Хотя распределения заметно асимметричны, большой объём данных позволяет применить **ЦПТ**, поэтому использование параметрического теста будет корректным.
#
# Проверим гипотезу с помощью **двухвыборочного t-теста Уэлча**.
#
# Выберем стандартный уровень статистической значимости α = 0.05.
#
# Если p_value < α, то отклоняем H₀ и считаем, что пользователи мобильных устройств действительно в среднем делают больше заказов
# Если p_value ≥ α, то нет статистических оснований отвергнуть H₀.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>Отличное обоснование выбранного теста

# %%
# Проведение t-теста
result, p_value = st.ttest_ind(
    mobile_orders,
    desktop_orders,
    equal_var = False,
    alternative='greater'
)

# Задаём уровень значимости
alpha = 0.05

# Выводим значение p_value
if p_value < alpha:
        print(f'Полученное значение p_value = {round(p_value, 3)} меньше критического уровня alpha={alpha}. Принимаем альтернативную гипотезу.')
else:
        print(f'Полученное значение p_value = {round(p_value, 3)} больше критического уровня alpha={alpha}. Отвергнуть нулевую гипотезу нельзя.')
# Out:
# Полученное значение p_value = 0.001 меньше критического уровня alpha=0.05. Принимаем альтернативную гипотезу.

# %% [markdown]
# Результаты теста показали, что различие в среднем количестве заказов между пользователями мобильных и стационарных устройств **статистически значимо**. Это позволяет **отвергнуть нулевую гипотезу** и считать, что пользователи **мобильных устройств совершают в среднем больше заказов**, чем пользователи стационарных устройств.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b>И сам он проведен верно!

# %% [markdown]
# ### Гипотеза о среднем времени между заказами
#
# **Гипотеза**: у пользователей мобильных устройств в среднем проходит больше времени между заказами, чем у пользователей стационарных устройств.
#
# - Нулевая гипотеза **H₀**: Среднее время между заказами у пользователей мобильных и стационарных устройств одинаково. Распределения одинаковы.
#
# - Альтернативная гипотеза **H₁**: Среднее время между заказами у пользователей мобильных устройств выше, чем у пользователей стационарных устройств.

# %%
# Удалим пропуски
autumn_filtered = autumn_df.dropna(subset = ['days_since_prev'])

# Находим пересекающихся пользователей
intersection_users = set(autumn_filtered[autumn_filtered['device_type_canonical'] == 'mobile']['user_id']).intersection(
    autumn_filtered[autumn_filtered['device_type_canonical'] == 'desktop']['user_id'])
                         
print(f'Количество пересекающихся пользователей: {len(intersection_users)}')
# Out:
# Количество пересекающихся пользователей: 3029

# %% [markdown]
# **3029 пользователей** совершали заказы с обоих типов устройств. Это означает, что выборки не являются независимыми, а значит применение t-теста может давать смещённые результаты. Так как в обеих выборках достаточное количество пользователей, пересекающихся пользователей лучше **исключить из анализа**, чтобы обеспечить независимость выборок и корректность статистического теста.

# %%
# Удаляем пересекающихся пользователей
autumn_filtered = autumn_filtered[~autumn_filtered['user_id'].isin(intersection_users)]

# Разделяем на две выборки
mobile_days = autumn_filtered[autumn_filtered['device_type_canonical'] == 'mobile']['days_since_prev']
desktop_days = autumn_filtered[autumn_filtered['device_type_canonical'] == 'desktop']['days_since_prev']

# Проверим базовые параметры
print(mobile_days.describe(), '\n\n', desktop_days.describe())
# Out:
# count    24775.000000
# mean        13.756731
# std         25.635633
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         15.000000
# max        148.000000
# Name: days_since_prev, dtype: float64
#
#  count    2271.000000
# mean       17.470718
# std        31.616701
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        21.000000
# max       146.000000
# Name: days_since_prev, dtype: float64

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Небольшие замечания и рекомендации💡:</b>Выполняя проверки можно еще  взглянуть на пересечения пользователей по группам и убедиться в независимости выборок

# %% [markdown]
# <div class="alert alert-info"> Стало еще лучше, спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Круто, что идея идея заинтересовала

# %% [markdown]
# Данные по времени между заказами имеют сильную асимметрию, множество нулей и выбросы (до 148 дней), использование параметрических тестов некорректно.
#
# Больше подходит **непараметрический тест Манна–Уитни**, который сравнивает распределения двух независимых выборок и не требует нормальности данных.
#
# Перед проведением статистического тестаисключим из анализа значения выше 99-го перцентиля, чтобы снизить влияние аномально больших значений.
#
# Выберем стандартный уровень статистической значимости α = 0.05.
#
# Если p_value < α, то отклоняем H₀ и считаем, что среднее время между заказами у пользоватаелей мобильных устройств больше, чем у пользователей стационарных устройств.
# Если p_value ≥ α, то нет статистических оснований отвергнуть H₀.

# %%
# Исключаем выбросы
mobile_filtered = mobile_days[mobile_days <= mobile_days.quantile(0.99)]
desktop_filtered = desktop_days[desktop_days <= desktop_days.quantile(0.99)]

# Проведение теста Манна–Уитни
result, p_value = st.mannwhitneyu(
    mobile_filtered,
    desktop_filtered,
    alternative='greater'
)

# Задаём уровень значимости
alpha = 0.05

# Выводим значение p_value
if p_value < alpha:
        print(f'Полученное значение p_value = {p_value} меньше критического уровня alpha={alpha}. Принимаем альтернативную гипотезу.')
else:
        print(f'Полученное значение p_value = {p_value} больше критического уровня alpha={alpha}. Отвергнуть нулевую гипотезу нельзя.')
# Out:
# Полученное значение p_value = 3.2047144973151827e-07 меньше критического уровня alpha=0.05. Принимаем альтернативную гипотезу.

# %% [markdown]
# <div class="alert alert-info"> Привет!
#
# Тут что-то не то, но я не понимаю что:(
#
# t-тест выдает те же значения
#
# тесты по столбцу created_ts_msk и ограничение данных по 99-му процентилю тоже показывают p_value около 0
#
# Подскажи пожалуйста, что делать в таких странных асимметричных распределениях
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Алёна, второй тест также проведен качественно, есть и обоснование выбора теста на основе необходимых проверок и формулировка взаимоисключающих гипотез и удобно настроенный вывод результатов и понятная заказчикам интерпретация. Очень хорошая работа и я не совсем понимаю что тебя смуило.
#
# При работе с ассиметричными распределениями, при условии достаточного объема выборки желательно всегда делать проверку выбросов и их фильтрацию, кстати можно ислользовать `ttest` в силу ЦПТ. Он будет иметь большую мощность, чем U-тест

# %% [markdown]
# <div class="alert alert-info"> Про предпочтительность t-теста поняла, тут решила оставить этот для разнообразия, спасибо за ответ!</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Тебе спасибо за грамотный вопрос, всегда приятно поделиться опытом)

# %% [markdown]
# Результаты теста показали, что различие в среднем времени между заказами между пользователями мобильных и стационарных устройств **статистически значимо**. Это позволяет **отвергнуть нулевую гипотезу** и считать, что пользователи мобильных устройств имеют большее среднее время между заказами, чем пользователи стационарных устройств.

# %% [markdown]
# **Промежуточный вывод**
#
# В ходе проверки гипотез были проанализированы различия в поведении пользователей мобильных и стационарных устройств за осенний период 2024 года.
#
# По результатам t-теста установлено, что пользователи мобильных устройств совершают **статистически значимо больше заказов**, чем пользователи стационарных устройств. Это подтверждает более высокую активность мобильных пользователей.
#
# При проверке второй гипотезы выявлено, что пользователи мобильных устройств имеют **большее среднее время между заказами**, чем пользователи стационарных устройств.

# %% [markdown]
# ## Общий вывод и рекомендации
#
# В ходе анализа были изучены данные более чем **270 тысяч заказов сервиса Яндекс Афиша** за период с июня по ноябрь 2024 года. После очистки и объединения данных проведён анализ сезонных изменений, пользовательской активности, распределения заказов по регионам и партнёрам, а также статистическая проверка гипотез.
#
# Данные показали выраженную сезонность — осенью наблюдается **рост количества заказов и активности пользователей** по сравнению с летом.
#
# Осенью пользователи чаще выбирали **театр и спортивные мероприятия**, тогда как доля концертов снизилась. Средняя стоимость билета незначительно уменьшилась, что может быть связано с акциями и выбором бюджетных событий. Активность пользователей максимальна в середине недели, при этом мобильные пользователи совершают заказы чаще и с меньшими интервалами между покупками. Среди регионов лидирует **Каменевский регион**, а основную долю выручки формируют партнёры **«Билеты без проблем»**, **«Лови билет!»**, **«Мой билет»** и **«Облачко»**.
#
# Анализ по регионам показал наличие выраженных лидеров — **Каменевский регион и Североярская область** формируют значительную часть заказов и мероприятий. Так, имеет смысл проводить анализ данных в региональном разрезе, поскольку активность и структура спроса существенно различаются между территориями.
#
# При проверке гипотез выявлено, что пользователи **мобильных устройств** совершают статистически значимо **больше заказов**, чем пользователи стационарных устройств, что подтверждает их более высокую активность. Однако при проверке второй гипотезы установлено, что у **мобильных пользователей** в среднем проходит больше времени между заказами, что может быть связано с особенностями использования приложения.
#
# **Рекомендации**
#
# Рекомендуется развивать **мобильное направление**, так как пользователи мобильных устройств демонстрируют наибольшую вовлечённость и долю заказов. Следует оптимизировать интерфейса, внедрить персональные рекомендации по интересам и истории заказов. Это позволит **повысить частоту повторных покупок и сократить средний интервал между заказами**.
#
# Для осеннего сезона можно усилить **продвижение театральных и спортивных мероприятий**, которые показали рост интереса, ввести сезонные акции.
#
# Также стоит поддерживать и развивать **партнёрства с лидирующими билетными сервисами** — "Билеты без проблем", "Мой билет", "Облачко". Им можно предложить совместные акции или программы лояльности, чтобы стимулировать пользователей за повторные покупки именно через эти платформы.
#
# Дополнительно можно провести анализ повторных заказов, чтобы понять, какие факторы влияют на удержание.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v1 <a class="tocSkip"> </h2>
#
# <b>Все супер!👍:</b> Алёна, итоговый вывод, как и весь проект в целом, выполнен классно! Он структурирован и содержит  наиболее значимые результаты по каждому пункту работы.
#
# Ответы на все главные вопросы команды даны!
#
# Очень интересный и разумный подход сделать упор при написании рекомендаций на указание широкого пула возможных стратегий повышения выручки. По моему опыту, для многих руководителей важно умение аналитика давать всеохватывающие и в то же время конкретные предложения как ты.
#
# Итоговые выводы - важная часть работы и в твоих будующих реальных проектах советую уделять ей не меньшее внимание. Бывают ситуации, когда у руководства нет времени вникать в весь проект и оценка твоих действий будет проводиться именно по ним.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#          Спасибо за проект! Ты приложила много усилий, чтобы довести его до конца, проделана огромная работа, и это видно невооруженным глазом, ты молодец!
#
# У тебя отлично развиты аналитические способности, владение инструментарием и умение формулировать выводы. Видно, что ты очень хорошо освоила материалы курса)
#
# Работа выполнена полностью по ТЗ и без ошибок, я возвращаю ее тебе, чтобы убедиться в отсутствии вопросов ко мне и если все хорошо, я сразу приму ее)
#
# **Отмечу положительные моменты**:
#
#         1. Все разложено по полочкам, всегда понятен ход твоих мыслей, приятно смотреть.
#
#         2. Понятные и логичные выводы на всех этапах работы.
#
#         3. Лаконичное оформление визуализаций и проекта в целом.
#
#         4. Внимание к деталям в анализе параметров
#
#         5. Оптимальное написание элементов кода
#
#
#
#
#
#
# **Поздравляю тебя, еще одна аналитическая работа попадает в твое портфолио!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту ревьювера**:
#          Алёна, спасибо за обратную связь, было приятно вместе поработать над этим проектом
